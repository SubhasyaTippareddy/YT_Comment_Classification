# %%
pip install contractions
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 8.0 MB/s eta 0:00:00
# ...

# %%
import re


def remove_URL(text: str) -> str:
    """
        Remove URLs from a sample string
    """
    return re.sub(r'https?://\S+|www\.\S+', ' ', text)


def remove_html(text: str) -> str:
    """
        Remove the html in sample text
    """
    html = re.compile(r'<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    return re.sub(html, ' ', text)


def remove_non_ascii(text: str) -> str:
    """
        Remove non-ASCII characters
    """
    return re.sub(r'[^\x00-\x7f]', r' ', text)


def remove_special_characters(text: str) -> str:
    """
        Remove special special characters, including symbols, emojis, and other graphic characters
    """
    emoji_pattern = re.compile(
        '['
        u'\U0001F600-\U0001F64F'  # emoticons
        u'\U0001F300-\U0001F5FF'  # symbols & pictographs
        u'\U0001F680-\U0001F6FF'  # transport & map symbols
        u'\U0001F1E0-\U0001F1FF'  # flags (iOS)
        u'\U00002702-\U000027B0'
        u'\U000024C2-\U0001F251'
        ']+',
        flags=re.UNICODE)
    return emoji_pattern.sub(r' ', text)


def remove_punct(text: str) -> str:
    """
        Remove the punctuation
    """
    return re.sub(r'[]!"$%&\'()*+,./:;=#@?[\\^_`{|}~-]+', ' ', text)


def remove_linebreak(text: str) -> str:
    """
        Remove linebreak ('\n', '\r')
    """
    return re.sub(r'/\\n+|\\r+|\n+|\r+/', r' ', text)
from contractions import fix as contractions_fix

# %%
def preprocessing_text(text: str) -> str:
    text = remove_non_ascii(text)
    text = remove_special_characters(text)
    text = text.lower()
    text = contractions_fix(text)
    text = remove_URL(text)
    text = remove_html(text)
    text = remove_linebreak(text)
    text = remove_punct(text)
    return text

# %%
import pandas as pd
data = pd.read_csv('pewdiepie.csv', engine = 'python')

data = data['Comment']
data.shape
# Out:
# (22366,)

# %%
data.head()
# Out:
# 0    Stupid ending. He's a real piece of work. Blas...
# 1                 methinks he doth protest to much   🤔
# 2    Surprised to see no mention of the underage pr...
# 3                                     Matt Gaetz? Geez
# 4    Why is he still a free man, ops, forgot it’s A...
# Name: Comment, dtype: object

# %%
data_processed = []
for i in data:
  data_processed.append(preprocessing_text(str(i)))

processed_data = pd.DataFrame(data_processed)
processed_data
# Out:
#                                                        0
# 0                       zee music company 106m subscribe
# 1      i just came to watch this to know how pewdiepi...
# 2      the funny thing is that s what mr beast said h...
# 3                     mrbeast really passed you know lol
# 4                                                 now
# ...                                                  ...
# 22361                                               nice
# 22362                                               nice
# 22363                   finally  the true first comment
# 22364                                         bigolcat l
# 22365                                     watch my vedio
#
# [22366 rows x 1 columns]

# %%
# Export whole dataset to the local machine as CSV File
csv_file = 'mkbhd_processeddata.csv'
jennys_processed_data.to_csv(csv_file, index=False)

from google.colab import files

files.download(csv_file)
